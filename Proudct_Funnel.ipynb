# %%
import pandas as pd
df = pd.read_csv('user_journey_data.csv')

# %%
df.head()
# Out:
#    user_id   event         timestamp
# 0        1   visit   2025-07-04 0:47
# 1        1  signup   2025-07-04 0:55
# 2        2   visit  2025-07-03 18:27
# 3        2  signup  2025-07-03 18:30
# 4        3   visit  2025-07-07 22:41

# %%
df_funnel = df["event"].value_counts()
df_funnel
# Out:
# event
# visit          915
# signup         649
# try_feature    334
# purchase       113
# Name: count, dtype: int64

# %%
# prompt: Create a funnel chart to present the user jounery

# !pip install plotly
import plotly.express as px

fig = px.funnel(df_funnel, x=df_funnel.index, y=df_funnel.values)
fig.show()
# Out:
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
